# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/CSAI Master') #uni 
#os.chdir('/content/drive/MyDrive/UniNotes/DRL')

# %%
# !pip install stable-baselines3==1.2.0
import stable_baselines3

print(f"{stable_baselines3.__version__=}")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stable-baselines3==1.2.0
#   Downloading stable_baselines3-1.2.0-py3-none-any.whl (161 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.0/162.0 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: gym>=0.17 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==1.2.0) (0.25.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==1.2.0) (1.22.4)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==1.2.0) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==1.2.0) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==1.2.0) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==1.2.0) (3.7.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym>=0.17->stable-baselines3==1.2.0) (0.0.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->stable-baselines3==1.2.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->stable-baselines3==1.2.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->stable-baselines3==1.2.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->stable-baselines3==1.2.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->stable-baselines3==1.2.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->stable-baselines3==1.2.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->stable-baselines3==1.2.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->stable-baselines3==1.2.0) (16.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==1.2.0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==1.2.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==1.2.0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==1.2.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==1.2.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==1.2.0) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==1.2.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==1.2.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==1.2.0) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==1.2.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->stable-baselines3==1.2.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->stable-baselines3==1.2.0) (1.3.0)
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-1.2.0
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# stable_baselines3.__version__='1.2.0'

# %%
pip install gymnasium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gymnasium
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.22.4)
# Collecting jax-jumpy>=1.0.0 (from gymnasium)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, jax-jumpy, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0

# %%
import gymnasium as gym
import numpy as np

print(f"{gym.__version__=}")
# Out:
# gym.__version__='0.28.1'

# %%
from stable_baselines3.ppo import MlpPolicy
#from stable_baselines3.ddpg import MlpPolicy

# %%
# !pip install mujoco==2.3.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mujoco==2.3.3
#   Downloading mujoco-2.3.3-2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 35.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mujoco==2.3.3) (1.4.0)
# Collecting glfw (from mujoco==2.3.3)
#   Downloading glfw-2.5.9-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.8/207.8 kB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mujoco==2.3.3) (1.22.4)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.10/dist-packages (from mujoco==2.3.3) (3.1.6)
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.5.9 mujoco-2.3.3

# %%
import mujoco
print(f"{mujoco.__version__=}")
# Out:
# mujoco.__version__='2.3.3'

# %%
class ChangeMassWrapper(gym.Wrapper):
    def __init__ (self, env, torso_mass =6):
        super().__init__ (env)

        self.torso_mass = torso_mass
        self.env.model.body_mass[1] = self.torso_mass

# %%
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import SubprocVecEnv
import time
from stable_baselines3 import SAC
from stable_baselines3 import PPO

# %%
env = make_vec_env('Hopper-v4', seed=0, vec_env_cls=SubprocVecEnv,
                   wrapper_class=ChangeMassWrapper,
                   wrapper_kwargs=dict(torso_mass=5)
                   )

env = VecNormalize(env, norm_obs=True, norm_reward=True)

# %%
model = SAC('MlpPolicy', env, 
            learning_rate=0.0003,  verbose = 2)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=3_000_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28       |
# |    ep_rew_mean     | 26       |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 254      |
# |    time_elapsed    | 0        |
# |    total timesteps | 112      |
# | train/             |          |
# |    actor_loss      | -3.01    |
# |    critic_loss     | 1.65     |
# |    ent_coef        | 0.997    |
# |    ent_coef_loss   | -0.0152  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | 19.1     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 143      |
# |    time_elapsed    | 1        |
# |    total timesteps | 177      |
# | train/             |          |
# |    actor_loss      | -4.42    |
# |    critic_loss     | 0.515    |
# |    ent_coef        | 0.978    |
# |    ent_coef_loss   | -0.113   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 17.8     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 115      |
# |    time_elapsed    | 2        |
# |    total timesteps | 267      |
# | train/             |          |
# |    actor_loss      | -4.87    |
# |    critic_loss     | 0.382    |
# |    ent_coef        | 0.952    |
# |    ent_coef_loss   | -0.249   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 166      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23       |
# |    ep_rew_mean     | 18.6     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 105      |
# |    time_elapsed    | 3        |
# |    total timesteps | 368      |
# | train/             |          |
# |    actor_loss      | -5.56    |
# |    critic_loss     | 0.341    |
# |    ent_coef        | 0.923    |
# |    ent_coef_loss   | -0.403   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.2     |
# |    ep_rew_mean     | 17.6     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 100      |
# |    time_elapsed    | 4        |
# |    total timesteps | 465      |
# | train/             |          |
# |    actor_loss      | -6.15    |
# |    critic_loss     | 0.232    |
# |    ent_coef        | 0.897    |
# |    ent_coef_loss   | -0.548   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 364      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | 17.1     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 97       |
# |    time_elapsed    | 5        |
# |    total timesteps | 548      |
# | train/             |          |
# |    actor_loss      | -6.45    |
# |    critic_loss     | 0.255    |
# |    ent_coef        | 0.875    |
# |    ent_coef_loss   | -0.671   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 447      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 16.7     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 94       |
# |    time_elapsed    | 6        |
# |    total timesteps | 621      |
# | train/             |          |
# |    actor_loss      | -6.77    |
# |    critic_loss     | 0.239    |
# |    ent_coef        | 0.856    |
# |    ent_coef_loss   | -0.783   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 520      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.7     |
# |    ep_rew_mean     | 19.6     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 85       |
# |    time_elapsed    | 9        |
# |    total timesteps | 791      |
# | train/             |          |
# |    actor_loss      | -7.63    |
# |    critic_loss     | 0.196    |
# |    ent_coef        | 0.814    |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 690      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.2     |
# |    ep_rew_mean     | 23.8     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 83       |
# |    time_elapsed    | 11       |
# |    total timesteps | 980      |
# | train/             |          |
# |    actor_loss      | -8.52    |
# |    critic_loss     | 0.139    |
# |    ent_coef        | 0.769    |
# |    ent_coef_loss   | -1.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 879      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.8     |
# |    ep_rew_mean     | 23.2     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 83       |
# |    time_elapsed    | 12       |
# |    total timesteps | 1073     |
# | train/             |          |
# |    actor_loss      | -9.18    |
# |    critic_loss     | 0.183    |
# |    ent_coef        | 0.748    |
# |    ent_coef_loss   | -1.44    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 972      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.9     |
# |    ep_rew_mean     | 33.7     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 84       |
# |    time_elapsed    | 17       |
# |    total timesteps | 1447     |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.535    |
# |    ent_coef        | 0.67     |
# |    ent_coef_loss   | -1.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1346     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | 34.7     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 84       |
# |    time_elapsed    | 19       |
# |    total timesteps | 1650     |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.356    |
# |    ent_coef        | 0.632    |
# |    ent_coef_loss   | -2.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1549     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.9     |
# |    ep_rew_mean     | 35.2     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 82       |
# |    time_elapsed    | 22       |
# |    total timesteps | 1865     |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.151    |
# |    ent_coef        | 0.593    |
# |    ent_coef_loss   | -2.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1764     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.1     |
# |    ep_rew_mean     | 37.9     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 79       |
# |    time_elapsed    | 27       |
# |    total timesteps | 2187     |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 0.259    |
# |    ent_coef        | 0.541    |
# |    ent_coef_loss   | -2.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2086     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.6     |
# |    ep_rew_mean     | 40       |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 80       |
# |    time_elapsed    | 31       |
# |    total timesteps | 2496     |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 0.173    |
# |    ent_coef        | 0.495    |
# |    ent_coef_loss   | -3.29    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2395     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.7     |
# |    ep_rew_mean     | 44.4     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 80       |
# |    time_elapsed    | 35       |
# |    total timesteps | 2858     |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.51     |
# |    ent_coef        | 0.446    |
# |    ent_coef_loss   | -3.68    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2757     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.1     |
# |    ep_rew_mean     | 44.9     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 79       |
# |    time_elapsed    | 41       |
# |    total timesteps | 3271     |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.167    |
# |    ent_coef        | 0.395    |
# |    ent_coef_loss   | -4.13    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3170     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.9     |
# |    ep_rew_mean     | 60.5     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 80       |
# |    time_elapsed    | 49       |
# |    total timesteps | 3953     |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 0.203    |
# |    ent_coef        | 0.324    |
# |    ent_coef_loss   | -4.99    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3852     |
# ---------------------------------

# %%
loaded_model.save('SAC_hopper_w3_3mil.zip')
#num_timesteps = model.num_timesteps

# %%
import gym
from stable_baselines3 import SAC

# Create and set up your environment
env = gym.make('Hopper-v4')  # Replace 'Hopper-v3' with your desired environment ID
env.reset()

# Load the model

loaded_model = SAC.load('SAC_hopper_w3_2mil.zip', env=env)

# Continue training the loaded model
loaded_model.learn(total_timesteps=3000000)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# |    n_updates       | 2131537  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 460      |
# |    ep_rew_mean     | 1.51e+03 |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 73       |
# |    time_elapsed    | 656      |
# |    total timesteps | 48311    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 4.69     |
# |    ent_coef        | 0.0543   |
# |    ent_coef_loss   | -0.802   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2134470  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 476      |
# |    ep_rew_mean     | 1.57e+03 |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 73       |
# |    time_elapsed    | 689      |
# |    total timesteps | 50836    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 4.38     |
# |    ent_coef        | 0.0571   |
# |    ent_coef_loss   | 0.189    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2136995  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 491      |
# |    ep_rew_mean     | 1.62e+03 |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 73       |
# |    time_elapsed    | 724      |
# |    total timesteps | 53494    |
# | train/             |          |
# |    actor_loss      | -291     |
# |    critic_loss     | 7.04     |
# |    ent_coef        | 0.0577   |
# |    ent_coef_loss   | -0.447   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2139653  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 516      |
# |    ep_rew_mean     | 1.71e+03 |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 73       |
# |    time_elapsed    | 770      |
# |    total timesteps | 56866    |
# | train/             |          |
# |    actor_loss      | -294     |
# |    critic_loss     | 34.6     |
# |    ent_coef        | 0.0533   |
# |    ent_coef_loss   | 0.55     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2143025  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 532      |
# |    ep_rew_mean     | 1.77e+03 |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 73       |
# |    time_elapsed    | 806      |
# |    total timesteps | 59609    |
# | train/             |          |
# |    actor_loss      | -293     |
# |    critic_loss     | 3.38     |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | -0.372   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2145768  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 546      |
# |    ep_rew_mean     | 1.82e+03 |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 73       |
# |    time_elapsed    | 840      |
# |    total timesteps | 62126    |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 6.61     |
# |    ent_coef        | 0.0519   |
# |    ent_coef_loss   | -0.219   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2148285  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 556      |
# |    ep_rew_mean     | 1.85e+03 |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 73       |
# |    time_elapsed    | 866      |
# |    total timesteps | 64074    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 4.34     |
# |    ent_coef        | 0.0523   |
# |    ent_coef_loss   | -0.347   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2150233  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 556      |
# |    ep_rew_mean     | 1.86e+03 |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 74       |
# |    time_elapsed    | 898      |
# |    total timesteps | 66519    |
# | train/             |          |
# |    actor_loss      | -297     |
# |    critic_loss     | 5.55     |
# |    ent_coef        | 0.0521   |
# |    ent_coef_loss   | 0.607    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2152678  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 562      |
# |    ep_rew_mean     | 1.89e+03 |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 74       |
# |    time_elapsed    | 944      |
# |    total timesteps | 69961    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 4.15     |
# |    ent_coef        | 0.049    |
# |    ent_coef_loss   | 0.248    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2156120  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 563      |
# |    ep_rew_mean     | 1.89e+03 |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 74       |
# |    time_elapsed    | 972      |
# |    total timesteps | 72132    |
# | train/             |          |
# |    actor_loss      | -298     |
# |    critic_loss     | 5.61     |
# |    ent_coef        | 0.0463   |
# |    ent_coef_loss   | 0.324    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2158291  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 556      |
# |    ep_rew_mean     | 1.87e+03 |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 74       |
# |    time_elapsed    | 983      |
# |    total timesteps | 72918    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 3.18     |
# |    ent_coef        | 0.0456   |
# |    ent_coef_loss   | 0.634    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2159077  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 561      |
# |    ep_rew_mean     | 1.88e+03 |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 74       |
# |    time_elapsed    | 1009     |
# |    total timesteps | 74923    |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 5.28     |
# |    ent_coef        | 0.048    |
# |    ent_coef_loss   | -0.451   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2161082  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 550      |
# |    ep_rew_mean     | 1.84e+03 |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 74       |
# |    time_elapsed    | 1011     |
# |    total timesteps | 75039    |
# | train/             |          |
# |    actor_loss      | -299     |
# |    critic_loss     | 3.69     |
# |    ent_coef        | 0.048    |
# |    ent_coef_loss   | -0.881   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2161198  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 538      |
# |    ep_rew_mean     | 1.81e+03 |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 74       |
# |    time_elapsed    | 1047     |
# |    total timesteps | 77802    |
# | train/             |          |
# |    actor_loss      | -305     |
# |    critic_loss     | 7.86     |
# |    ent_coef        | 0.0491   |
# |    ent_coef_loss   | 0.435    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2163961  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 527      |
# |    ep_rew_mean     | 1.78e+03 |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 74       |
# |    time_elapsed    | 1076     |
# |    total timesteps | 79890    |
# | train/             |          |
# |    actor_loss      | -302     |
# |    critic_loss     | 3.76     |
# |    ent_coef        | 0.0489   |
# |    ent_coef_loss   | -0.821   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2166049  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 537      |
# |    ep_rew_mean     | 1.82e+03 |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 74       |
# |    time_elapsed    | 1122     |
# |    total timesteps | 83328    |
# | train/             |          |
# |    actor_loss      | -298     |
# |    critic_loss     | 14.2     |
# |    ent_coef        | 0.0512   |
# |    ent_coef_loss   | 0.271    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2169487  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 549      |
# |    ep_rew_mean     | 1.86e+03 |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 74       |
# |    time_elapsed    | 1159     |
# |    total timesteps | 86159    |
# | train/             |          |
# |    actor_loss      | -295     |
# |    critic_loss     | 6.52     |
# |    ent_coef        | 0.0511   |
# |    ent_coef_loss   | -0.69    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2172318  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 562      |
# |    ep_rew_mean     | 1.91e+03 |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 74       |
# |    time_elapsed    | 1206     |
# |    total timesteps | 89762    |
# | train/             |          |
# |    actor_loss      | -300     |
# |    critic_loss     | 4.99     |
# |    ent_coef        | 0.0508   |
# |    ent_coef_loss   | -0.204   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2175921  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 569      |
# |    ep_rew_mean     | 1.93e+03 |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 74       |
# |    time_elapsed    | 1252     |
# |    total timesteps | 93119    |
# | train/             |          |
# |    actor_loss      | -301     |
# |    critic_loss     | 5.87     |
# |    ent_coef        | 0.0492   |
# |    ent_coef_loss   | -0.369   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2179278  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 587      |
# |    ep_rew_mean     | 1.99e+03 |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 74       |
# |    time_elapsed    | 1306     |
# |    total timesteps | 97119    |
# | train/             |          |
# |    actor_loss      | -293     |
# |    critic_loss     | 4.62     |
# |    ent_coef        | 0.0476   |
# |    ent_coef_loss   | 0.156    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2183278  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 619      |
# |    ep_rew_mean     | 2.11e+03 |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 74       |
# |    time_elapsed    | 1359     |
# |    total timesteps | 101119   |
# | train/             |          |
# |    actor_loss      | -302     |
# |    critic_loss     | 4.24     |
# |    ent_coef        | 0.0462   |
# |    ent_coef_loss   | 0.185    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2187278  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 640      |
# |    ep_rew_mean     | 2.19e+03 |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 74       |
# |    time_elapsed    | 1407     |
# |    total timesteps | 104687   |
# | train/             |          |
# |    actor_loss      | -305     |
# |    critic_loss     | 3.76     |
# |    ent_coef        | 0.0436   |
# |    ent_coef_loss   | -0.115   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2190846  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 653      |
# |    ep_rew_mean     | 2.24e+03 |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 74       |
# |    time_elapsed    | 1438     |
# |    total timesteps | 107082   |
# | train/             |          |
# |    actor_loss      | -304     |
# |    critic_loss     | 2.94     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | 0.383    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2193241  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 667      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 74       |
# |    time_elapsed    | 1472     |
# |    total timesteps | 109615   |
# | train/             |          |
# |    actor_loss      | -310     |
# |    critic_loss     | 2.92     |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | 0.121    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2195774  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 660      |
# |    ep_rew_mean     | 2.28e+03 |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 74       |
# |    time_elapsed    | 1496     |
# |    total timesteps | 111423   |
# | train/             |          |
# |    actor_loss      | -305     |
# |    critic_loss     | 5.81     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2197582  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 665      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 74       |
# |    time_elapsed    | 1542     |
# |    total timesteps | 114782   |
# | train/             |          |
# |    actor_loss      | -310     |
# |    critic_loss     | 3.93     |
# |    ent_coef        | 0.0439   |
# |    ent_coef_loss   | -0.0536  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2200941  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 660      |
# |    ep_rew_mean     | 2.29e+03 |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 74       |
# |    time_elapsed    | 1570     |
# |    total timesteps | 116837   |
# | train/             |          |
# |    actor_loss      | -308     |
# |    critic_loss     | 2.67     |
# |    ent_coef        | 0.043    |
# |    ent_coef_loss   | 0.129    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2202996  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 659      |
# |    ep_rew_mean     | 2.28e+03 |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 74       |
# |    time_elapsed    | 1602     |
# |    total timesteps | 119347   |
# | train/             |          |
# |    actor_loss      | -308     |
# |    critic_loss     | 3.06     |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -0.399   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2205506  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 648      |
# |    ep_rew_mean     | 2.25e+03 |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 74       |
# |    time_elapsed    | 1633     |
# |    total timesteps | 121655   |
# | train/             |          |
# |    actor_loss      | -298     |
# |    critic_loss     | 6.2      |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | -0.276   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2207814  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 654      |
# |    ep_rew_mean     | 2.27e+03 |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 74       |
# |    time_elapsed    | 1678     |
# |    total timesteps | 124963   |
# | train/             |          |
# |    actor_loss      | -308     |
# |    critic_loss     | 3.9      |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | 1.36     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2211122  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 656      |
# |    ep_rew_mean     | 2.28e+03 |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 74       |
# |    time_elapsed    | 1714     |
# |    total timesteps | 127684   |
# | train/             |          |
# |    actor_loss      | -311     |
# |    critic_loss     | 3.31     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | -0.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2213843  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 670      |
# |    ep_rew_mean     | 2.33e+03 |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 74       |
# |    time_elapsed    | 1758     |
# |    total timesteps | 131046   |
# | train/             |          |
# |    actor_loss      | -305     |
# |    critic_loss     | 5.28     |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | 0.773    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2217205  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 678      |
# |    ep_rew_mean     | 2.36e+03 |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 74       |
# |    time_elapsed    | 1803     |
# |    total timesteps | 134343   |
# | train/             |          |
# |    actor_loss      | -311     |
# |    critic_loss     | 4.66     |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | 0.349    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2220502  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 673      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 74       |
# |    time_elapsed    | 1842     |
# |    total timesteps | 137228   |
# | train/             |          |
# |    actor_loss      | -313     |
# |    critic_loss     | 5.16     |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | -0.421   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2223387  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 686      |
# |    ep_rew_mean     | 2.39e+03 |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 74       |
# |    time_elapsed    | 1888     |
# |    total timesteps | 140704   |
# | train/             |          |
# |    actor_loss      | -313     |
# |    critic_loss     | 1.97     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2226863  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 688      |
# |    ep_rew_mean     | 2.4e+03  |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 74       |
# |    time_elapsed    | 1901     |
# |    total timesteps | 141676   |
# | train/             |          |
# |    actor_loss      | -317     |
# |    critic_loss     | 3.85     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | -0.348   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2227835  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 694      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 74       |
# |    time_elapsed    | 1937     |
# |    total timesteps | 144321   |
# | train/             |          |
# |    actor_loss      | -309     |
# |    critic_loss     | 2.9      |
# |    ent_coef        | 0.0387   |
# |    ent_coef_loss   | -0.322   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2230480  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 2.54e+03 |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 74       |
# |    time_elapsed    | 1980     |
# |    total timesteps | 147594   |
# | train/             |          |
# |    actor_loss      | -308     |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | -0.0471  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2233753  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 2.54e+03 |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 74       |
# |    time_elapsed    | 2018     |
# |    total timesteps | 150371   |
# | train/             |          |
# |    actor_loss      | -309     |
# |    critic_loss     | 4.24     |
# |    ent_coef        | 0.0373   |
# |    ent_coef_loss   | 0.0491   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2236530  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 745      |
# |    ep_rew_mean     | 2.61e+03 |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 74       |
# |    time_elapsed    | 2071     |
# |    total timesteps | 154371   |
# | train/             |          |
# |    actor_loss      | -314     |
# |    critic_loss     | 2.35     |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | -1.18    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2240530  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 744      |
# |    ep_rew_mean     | 2.61e+03 |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 74       |
# |    time_elapsed    | 2116     |
# |    total timesteps | 157718   |
# | train/             |          |
# |    actor_loss      | -309     |
# |    critic_loss     | 3.89     |
# |    ent_coef        | 0.037    |
# |    ent_coef_loss   | 0.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2243877  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 756      |
# |    ep_rew_mean     | 2.65e+03 |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 74       |
# |    time_elapsed    | 2169     |
# |    total timesteps | 161718   |
# | train/             |          |
# |    actor_loss      | -315     |
# |    critic_loss     | 5.21     |
# |    ent_coef        | 0.0364   |
# |    ent_coef_loss   | -0.177   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2247877  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 2.67e+03 |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 74       |
# |    time_elapsed    | 2225     |
# |    total timesteps | 165718   |
# | train/             |          |
# |    actor_loss      | -309     |
# |    critic_loss     | 2.31     |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | 0.141    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2251877  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 766      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 74       |
# |    time_elapsed    | 2279     |
# |    total timesteps | 169718   |
# | train/             |          |
# |    actor_loss      | -307     |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | 0.744    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2255877  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 760      |
# |    ep_rew_mean     | 2.67e+03 |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 74       |
# |    time_elapsed    | 2325     |
# |    total timesteps | 173143   |
# | train/             |          |
# |    actor_loss      | -314     |
# |    critic_loss     | 2.23     |
# |    ent_coef        | 0.034    |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2259302  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 754      |
# |    ep_rew_mean     | 2.65e+03 |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 74       |
# |    time_elapsed    | 2370     |
# |    total timesteps | 176511   |
# | train/             |          |
# |    actor_loss      | -315     |
# |    critic_loss     | 3.28     |
# |    ent_coef        | 0.0341   |
# |    ent_coef_loss   | 0.322    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2262670  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 758      |
# |    ep_rew_mean     | 2.67e+03 |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 74       |
# |    time_elapsed    | 2422     |
# |    total timesteps | 180511   |
# | train/             |          |
# |    actor_loss      | -316     |
# |    critic_loss     | 3.05     |
# |    ent_coef        | 0.0336   |
# |    ent_coef_loss   | 0.532    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2266670  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 768      |
# |    ep_rew_mean     | 2.7e+03  |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 74       |
# |    time_elapsed    | 2467     |
# |    total timesteps | 183874   |
# | train/             |          |
# |    actor_loss      | -316     |
# |    critic_loss     | 2.36     |
# |    ent_coef        | 0.0325   |
# |    ent_coef_loss   | -1.71    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2270033  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 769      |
# |    ep_rew_mean     | 2.7e+03  |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 74       |
# |    time_elapsed    | 2501     |
# |    total timesteps | 186466   |
# | train/             |          |
# |    actor_loss      | -319     |
# |    critic_loss     | 1.78     |
# |    ent_coef        | 0.0335   |
# |    ent_coef_loss   | -1.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2272625  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 790      |
# |    ep_rew_mean     | 2.78e+03 |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 74       |
# |    time_elapsed    | 2554     |
# |    total timesteps | 190466   |
# | train/             |          |
# |    actor_loss      | -321     |
# |    critic_loss     | 2.22     |
# |    ent_coef        | 0.0318   |
# |    ent_coef_loss   | -1.52    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2276625  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 767      |
# |    ep_rew_mean     | 2.69e+03 |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 74       |
# |    time_elapsed    | 2568     |
# |    total timesteps | 191476   |
# | train/             |          |
# |    actor_loss      | -317     |
# |    critic_loss     | 3.44     |
# |    ent_coef        | 0.032    |
# |    ent_coef_loss   | 0.234    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2277635  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 759      |
# |    ep_rew_mean     | 2.67e+03 |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 74       |
# |    time_elapsed    | 2586     |
# |    total timesteps | 192762   |
# | train/             |          |
# |    actor_loss      | -318     |
# |    critic_loss     | 3.17     |
# |    ent_coef        | 0.0325   |
# |    ent_coef_loss   | -0.0151  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2278921  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 762      |
# |    ep_rew_mean     | 2.67e+03 |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 74       |
# |    time_elapsed    | 2624     |
# |    total timesteps | 195532   |
# | train/             |          |
# |    actor_loss      | -318     |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.0323   |
# |    ent_coef_loss   | 0.442    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2281691  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 773      |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 74       |
# |    time_elapsed    | 2669     |
# |    total timesteps | 198909   |
# | train/             |          |
# |    actor_loss      | -314     |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0333   |
# |    ent_coef_loss   | -0.581   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2285068  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 761      |
# |    ep_rew_mean     | 2.67e+03 |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 74       |
# |    time_elapsed    | 2697     |
# |    total timesteps | 201014   |
# | train/             |          |
# |    actor_loss      | -320     |
# |    critic_loss     | 3.57     |
# |    ent_coef        | 0.0329   |
# |    ent_coef_loss   | 0.184    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2287173  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 752      |
# |    ep_rew_mean     | 2.64e+03 |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 74       |
# |    time_elapsed    | 2722     |
# |    total timesteps | 202900   |
# | train/             |          |
# |    actor_loss      | -315     |
# |    critic_loss     | 4.15     |
# |    ent_coef        | 0.0327   |
# |    ent_coef_loss   | -0.368   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2289059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 743      |
# |    ep_rew_mean     | 2.61e+03 |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 74       |
# |    time_elapsed    | 2755     |
# |    total timesteps | 205376   |
# | train/             |          |
# |    actor_loss      | -313     |
# |    critic_loss     | 3.36     |
# |    ent_coef        | 0.0324   |
# |    ent_coef_loss   | -0.0363  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2291535  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 719      |
# |    ep_rew_mean     | 2.52e+03 |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 74       |
# |    time_elapsed    | 2767     |
# |    total timesteps | 206266   |
# | train/             |          |
# |    actor_loss      | -317     |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.0323   |
# |    ent_coef_loss   | 0.421    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2292425  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 714      |
# |    ep_rew_mean     | 2.5e+03  |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 74       |
# |    time_elapsed    | 2798     |
# |    total timesteps | 208614   |
# | train/             |          |
# |    actor_loss      | -314     |
# |    critic_loss     | 3.17     |
# |    ent_coef        | 0.0319   |
# |    ent_coef_loss   | 0.802    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2294773  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 692      |
# |    ep_rew_mean     | 2.43e+03 |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 74       |
# |    time_elapsed    | 2816     |
# |    total timesteps | 209922   |
# | train/             |          |
# |    actor_loss      | -312     |
# |    critic_loss     | 23.4     |
# |    ent_coef        | 0.032    |
# |    ent_coef_loss   | 1.44     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2296081  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 702      |
# |    ep_rew_mean     | 2.47e+03 |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 74       |
# |    time_elapsed    | 2842     |
# |    total timesteps | 211889   |
# | train/             |          |
# |    actor_loss      | -312     |
# |    critic_loss     | 3.38     |
# |    ent_coef        | 0.033    |
# |    ent_coef_loss   | -0.354   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2298048  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 709      |
# |    ep_rew_mean     | 2.49e+03 |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 74       |
# |    time_elapsed    | 2888     |
# |    total timesteps | 215235   |
# | train/             |          |
# |    actor_loss      | -317     |
# |    critic_loss     | 3.23     |
# |    ent_coef        | 0.034    |
# |    ent_coef_loss   | 0.714    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2301394  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 710      |
# |    ep_rew_mean     | 2.49e+03 |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 74       |
# |    time_elapsed    | 2933     |
# |    total timesteps | 218582   |
# | train/             |          |
# |    actor_loss      | -319     |
# |    critic_loss     | 3.2      |
# |    ent_coef        | 0.0332   |
# |    ent_coef_loss   | -0.336   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2304741  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 722      |
# |    ep_rew_mean     | 2.53e+03 |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 74       |
# |    time_elapsed    | 2987     |
# |    total timesteps | 222582   |
# | train/             |          |
# |    actor_loss      | -316     |
# |    critic_loss     | 3.06     |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | 1.2      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2308741  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 719      |
# |    ep_rew_mean     | 2.52e+03 |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 74       |
# |    time_elapsed    | 3037     |
# |    total timesteps | 226308   |
# | train/             |          |
# |    actor_loss      | -314     |
# |    critic_loss     | 3.44     |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | 0.336    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2312467  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 2.55e+03 |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 74       |
# |    time_elapsed    | 3090     |
# |    total timesteps | 230308   |
# | train/             |          |
# |    actor_loss      | -309     |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.0342   |
# |    ent_coef_loss   | -0.153   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2316467  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 2.54e+03 |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 74       |
# |    time_elapsed    | 3145     |
# |    total timesteps | 234308   |
# | train/             |          |
# |    actor_loss      | -324     |
# |    critic_loss     | 1.75     |
# |    ent_coef        | 0.033    |
# |    ent_coef_loss   | -0.297   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2320467  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 2.55e+03 |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 74       |
# |    time_elapsed    | 3200     |
# |    total timesteps | 238308   |
# | train/             |          |
# |    actor_loss      | -321     |
# |    critic_loss     | 1.98     |
# |    ent_coef        | 0.0323   |
# |    ent_coef_loss   | 0.174    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2324467  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 714      |
# |    ep_rew_mean     | 2.51e+03 |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 74       |
# |    time_elapsed    | 3238     |
# |    total timesteps | 241110   |
# | train/             |          |
# |    actor_loss      | -317     |
# |    critic_loss     | 2.18     |
# |    ent_coef        | 0.0331   |
# |    ent_coef_loss   | 0.469    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2327269  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 720      |
# |    ep_rew_mean     | 2.53e+03 |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 74       |
# |    time_elapsed    | 3290     |
# |    total timesteps | 245110   |
# | train/             |          |
# |    actor_loss      | -322     |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.0321   |
# |    ent_coef_loss   | 0.508    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2331269  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 2.55e+03 |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 74       |
# |    time_elapsed    | 3344     |
# |    total timesteps | 249110   |
# | train/             |          |
# |    actor_loss      | -310     |
# |    critic_loss     | 2.22     |
# |    ent_coef        | 0.0323   |
# |    ent_coef_loss   | 0.335    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2335269  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 721      |
# |    ep_rew_mean     | 2.54e+03 |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 74       |
# |    time_elapsed    | 3389     |
# |    total timesteps | 252596   |
# | train/             |          |
# |    actor_loss      | -314     |
# |    critic_loss     | 3.75     |
# |    ent_coef        | 0.0327   |
# |    ent_coef_loss   | -0.631   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2338755  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 698      |
# |    ep_rew_mean     | 2.45e+03 |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 74       |
# |    time_elapsed    | 3403     |
# |    total timesteps | 253654   |
# | train/             |          |
# |    actor_loss      | -318     |
# |    critic_loss     | 2.99     |
# |    ent_coef        | 0.0324   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2339813  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 697      |
# |    ep_rew_mean     | 2.45e+03 |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 74       |
# |    time_elapsed    | 3438     |
# |    total timesteps | 256132   |
# | train/             |          |
# |    actor_loss      | -324     |
# |    critic_loss     | 1.99     |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | -0.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2342291  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 661      |
# |    ep_rew_mean     | 2.32e+03 |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 74       |
# |    time_elapsed    | 3443     |
# |    total timesteps | 256589   |
# | train/             |          |
# |    actor_loss      | -319     |
# |    critic_loss     | 2.1      |
# |    ent_coef        | 0.0308   |
# |    ent_coef_loss   | -0.863   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2342748  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 658      |
# |    ep_rew_mean     | 2.3e+03  |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 74       |
# |    time_elapsed    | 3452     |
# |    total timesteps | 257226   |
# | train/             |          |
# |    actor_loss      | -319     |
# |    critic_loss     | 2.79     |
# |    ent_coef        | 0.0321   |
# |    ent_coef_loss   | 0.328    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2343385  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 677      |
# |    ep_rew_mean     | 2.37e+03 |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 74       |
# |    time_elapsed    | 3497     |
# |    total timesteps | 260472   |
# | train/             |          |
# |    actor_loss      | -320     |
# |    critic_loss     | 3.85     |
# |    ent_coef        | 0.0336   |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2346631  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 665      |
# |    ep_rew_mean     | 2.33e+03 |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 74       |
# |    time_elapsed    | 3518     |
# |    total timesteps | 262001   |
# | train/             |          |
# |    actor_loss      | -321     |
# |    critic_loss     | 2.7      |
# |    ent_coef        | 0.0339   |
# |    ent_coef_loss   | 0.422    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2348160  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 651      |
# |    ep_rew_mean     | 2.28e+03 |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 74       |
# |    time_elapsed    | 3545     |
# |    total timesteps | 264041   |
# | train/             |          |
# |    actor_loss      | -319     |
# |    critic_loss     | 6.8      |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2350200  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 670      |
# |    ep_rew_mean     | 2.35e+03 |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 74       |
# |    time_elapsed    | 3598     |
# |    total timesteps | 268041   |
# | train/             |          |
# |    actor_loss      | -314     |
# |    critic_loss     | 3.88     |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | 1.37     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2354200  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 687      |
# |    ep_rew_mean     | 2.41e+03 |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 74       |
# |    time_elapsed    | 3646     |
# |    total timesteps | 271632   |
# | train/             |          |
# |    actor_loss      | -318     |
# |    critic_loss     | 3.19     |
# |    ent_coef        | 0.0366   |
# |    ent_coef_loss   | 0.441    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2357791  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 696      |
# |    ep_rew_mean     | 2.45e+03 |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 74       |
# |    time_elapsed    | 3690     |
# |    total timesteps | 274978   |
# | train/             |          |
# |    actor_loss      | -314     |
# |    critic_loss     | 3.12     |
# |    ent_coef        | 0.0358   |
# ...
# |    ent_coef_loss   | -0.146   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3013683  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 826      |
# |    ep_rew_mean     | 3.11e+03 |
# | time/              |          |
# |    episodes        | 1208     |
# |    fps             | 74       |
# |    time_elapsed    | 12533    |
# |    total timesteps | 930702   |
# | train/             |          |
# |    actor_loss      | -343     |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | -0.841   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3016861  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 827      |
# |    ep_rew_mean     | 3.12e+03 |
# | time/              |          |
# |    episodes        | 1212     |
# |    fps             | 74       |
# |    time_elapsed    | 12586    |
# |    total timesteps | 934690   |
# | train/             |          |
# |    actor_loss      | -343     |
# |    critic_loss     | 0.76     |
# |    ent_coef        | 0.0209   |
# |    ent_coef_loss   | -0.826   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3020849  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 822      |
# |    ep_rew_mean     | 3.1e+03  |
# | time/              |          |
# |    episodes        | 1216     |
# |    fps             | 74       |
# |    time_elapsed    | 12630    |
# |    total timesteps | 937966   |
# | train/             |          |
# |    actor_loss      | -340     |
# |    critic_loss     | 2.13     |
# |    ent_coef        | 0.0199   |
# |    ent_coef_loss   | 0.603    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3024125  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 817      |
# |    ep_rew_mean     | 3.09e+03 |
# | time/              |          |
# |    episodes        | 1220     |
# |    fps             | 74       |
# |    time_elapsed    | 12676    |
# |    total timesteps | 941485   |
# | train/             |          |
# |    actor_loss      | -343     |
# |    critic_loss     | 3.06     |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | -0.605   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3027644  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 810      |
# |    ep_rew_mean     | 3.06e+03 |
# | time/              |          |
# |    episodes        | 1224     |
# |    fps             | 74       |
# |    time_elapsed    | 12714    |
# |    total timesteps | 944304   |
# | train/             |          |
# |    actor_loss      | -337     |
# |    critic_loss     | 2.36     |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | 0.99     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3030463  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 806      |
# |    ep_rew_mean     | 3.05e+03 |
# | time/              |          |
# |    episodes        | 1228     |
# |    fps             | 74       |
# |    time_elapsed    | 12755    |
# |    total timesteps | 947311   |
# | train/             |          |
# |    actor_loss      | -339     |
# |    critic_loss     | 1.93     |
# |    ent_coef        | 0.0199   |
# |    ent_coef_loss   | 0.565    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3033470  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 3.03e+03 |
# | time/              |          |
# |    episodes        | 1232     |
# |    fps             | 74       |
# |    time_elapsed    | 12796    |
# |    total timesteps | 950345   |
# | train/             |          |
# |    actor_loss      | -343     |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.0201   |
# |    ent_coef_loss   | -0.714   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3036504  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 804      |
# |    ep_rew_mean     | 3.05e+03 |
# | time/              |          |
# |    episodes        | 1236     |
# |    fps             | 74       |
# |    time_elapsed    | 12845    |
# |    total timesteps | 954042   |
# | train/             |          |
# |    actor_loss      | -341     |
# |    critic_loss     | 1.39     |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | -0.364   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3040201  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 791      |
# |    ep_rew_mean     | 3e+03    |
# | time/              |          |
# |    episodes        | 1240     |
# |    fps             | 74       |
# |    time_elapsed    | 12879    |
# |    total timesteps | 956563   |
# | train/             |          |
# |    actor_loss      | -340     |
# |    critic_loss     | 3.22     |
# |    ent_coef        | 0.0204   |
# |    ent_coef_loss   | 0.63     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3042722  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 778      |
# |    ep_rew_mean     | 2.95e+03 |
# | time/              |          |
# |    episodes        | 1244     |
# |    fps             | 74       |
# |    time_elapsed    | 12913    |
# |    total timesteps | 959203   |
# | train/             |          |
# |    actor_loss      | -336     |
# |    critic_loss     | 1.56     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | 0.93     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3045362  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 778      |
# |    ep_rew_mean     | 2.96e+03 |
# | time/              |          |
# |    episodes        | 1248     |
# |    fps             | 74       |
# |    time_elapsed    | 12955    |
# |    total timesteps | 962405   |
# | train/             |          |
# |    actor_loss      | -341     |
# |    critic_loss     | 1.47     |
# |    ent_coef        | 0.0217   |
# |    ent_coef_loss   | 0.345    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3048564  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 771      |
# |    ep_rew_mean     | 2.93e+03 |
# | time/              |          |
# |    episodes        | 1252     |
# |    fps             | 74       |
# |    time_elapsed    | 12993    |
# |    total timesteps | 965207   |
# | train/             |          |
# |    actor_loss      | -344     |
# |    critic_loss     | 2.03     |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | 0.0492   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3051366  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 777      |
# |    ep_rew_mean     | 2.95e+03 |
# | time/              |          |
# |    episodes        | 1256     |
# |    fps             | 74       |
# |    time_elapsed    | 13044    |
# |    total timesteps | 969125   |
# | train/             |          |
# |    actor_loss      | -344     |
# |    critic_loss     | 1.28     |
# |    ent_coef        | 0.0201   |
# |    ent_coef_loss   | 0.229    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3055284  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 790      |
# |    ep_rew_mean     | 3e+03    |
# | time/              |          |
# |    episodes        | 1260     |
# |    fps             | 74       |
# |    time_elapsed    | 13097    |
# |    total timesteps | 973118   |
# | train/             |          |
# |    actor_loss      | -341     |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | 0.815    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3059277  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 790      |
# |    ep_rew_mean     | 3e+03    |
# | time/              |          |
# |    episodes        | 1264     |
# |    fps             | 74       |
# |    time_elapsed    | 13142    |
# |    total timesteps | 976549   |
# | train/             |          |
# |    actor_loss      | -342     |
# |    critic_loss     | 0.747    |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | 0.287    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3062708  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 790      |
# |    ep_rew_mean     | 3e+03    |
# | time/              |          |
# |    episodes        | 1268     |
# |    fps             | 74       |
# |    time_elapsed    | 13190    |
# |    total timesteps | 979983   |
# | train/             |          |
# |    actor_loss      | -339     |
# |    critic_loss     | 0.981    |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | 0.0519   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3066142  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 802      |
# |    ep_rew_mean     | 3.04e+03 |
# | time/              |          |
# |    episodes        | 1272     |
# |    fps             | 74       |
# |    time_elapsed    | 13242    |
# |    total timesteps | 983831   |
# | train/             |          |
# |    actor_loss      | -343     |
# |    critic_loss     | 1.79     |
# |    ent_coef        | 0.02     |
# |    ent_coef_loss   | 0.718    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3069990  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 801      |
# |    ep_rew_mean     | 3.04e+03 |
# | time/              |          |
# |    episodes        | 1276     |
# |    fps             | 74       |
# |    time_elapsed    | 13282    |
# |    total timesteps | 986785   |
# | train/             |          |
# |    actor_loss      | -340     |
# |    critic_loss     | 1.06     |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | -0.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3072944  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 795      |
# |    ep_rew_mean     | 3.01e+03 |
# | time/              |          |
# |    episodes        | 1280     |
# |    fps             | 74       |
# |    time_elapsed    | 13314    |
# |    total timesteps | 989053   |
# | train/             |          |
# |    actor_loss      | -341     |
# |    critic_loss     | 1.65     |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3075212  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 800      |
# |    ep_rew_mean     | 3.03e+03 |
# | time/              |          |
# |    episodes        | 1284     |
# |    fps             | 74       |
# |    time_elapsed    | 13364    |
# |    total timesteps | 992650   |
# | train/             |          |
# |    actor_loss      | -342     |
# |    critic_loss     | 1.19     |
# |    ent_coef        | 0.0201   |
# |    ent_coef_loss   | -0.237   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3078809  |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1ac87f3ede7f> in <cell line: 13>()
#      11
#      12 # Continue training the loaded model
# ---> 13 loaded_model.learn(total_timesteps=3000000)
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/sac/sac.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     289     ) -> OffPolicyAlgorithm:
#     290
# --> 291         return super(SAC, self).learn(
#     292             total_timesteps=total_timesteps,
#     293             callback=callback,
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     369                 # Special case when the user passes `gradient_steps=0`
#     370                 if gradient_steps > 0:
# --> 371                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     372
#     373         callback.on_training_end()
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/sac/sac.py in train(self, gradient_steps, batch_size)
#     248             self.critic.optimizer.zero_grad()
#     249             critic_loss.backward()
# --> 250             self.critic.optimizer.step()
#     251
#     252             # Compute actor loss
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     278                                                f"but got {result}.")
#     279
# --> 280                 out = func(*args, **kwargs)
#     281                 self._optimizer_step_code()
#     282
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      31         try:
#      32             torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33             ret = func(self, *args, **kwargs)
#      34         finally:
#      35             torch.set_grad_enabled(prev_grad)
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in step(self, closure)
#     139                 state_steps)
#     140
# --> 141             adam(
#     142                 params_with_grad,
#     143                 grads,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     279         func = _single_tensor_adam
#     280
# --> 281     func(params,
#     282          grads,
#     283          exp_avgs,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     423     assert not differentiable, "_foreach ops don't support autograd"
#     424
# --> 425     grouped_tensors = _group_tensors_by_device_and_dtype([params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps])
#     426     for (device_params, device_grads, device_exp_avgs, device_exp_avg_sqs,
#     427          device_max_exp_avg_sqs, device_state_steps) in grouped_tensors.values():
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     112     @functools.wraps(func)
#     113     def decorate_context(*args, **kwargs):
# --> 114         with ctx_factory():
#     115             return func(*args, **kwargs)
#     116
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/grad_mode.py in __exit__(self, exc_type, exc_value, traceback)
#      56
#      57     def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
# ---> 58         torch.set_grad_enabled(self.prev)
#      59
#      60
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/grad_mode.py in __init__(self, mode)
#     147     """
#     148
# --> 149     def __init__(self, mode: bool) -> None:
#     150         self.prev = torch.is_grad_enabled()
#     151         torch._C._set_grad_enabled(mode)
#
# KeyboardInterrupt:

# %%
os.chdir('/content/drive/MyDrive/CSAI Master/DRL')
loaded_model = SAC.load('SAC_hopper_w3_3mil', env=env)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def evaluate(model, num_episodes=100, deterministic=True):
    """
    Evaluate a RL agent
    :param model: (BaseRLModel object) the RL Agent
    :param num_episodes: (int) number of episodes to evaluate it
    :return: (float) Mean reward for the last num_episodes
    """
    
    vec_env = model.get_env()
    all_episode_rewards = []
    for i in range(num_episodes):
        episode_rewards = []
        done = False
        obs = vec_env.reset()
        while not done:
           
            action, _states = model.predict(obs, deterministic=deterministic)
           
            obs, reward, done, info = vec_env.step(action)
            episode_rewards.append(reward)

        all_episode_rewards.append(sum(episode_rewards))

    mean_episode_reward = np.mean(all_episode_rewards)
    print("Mean reward:", mean_episode_reward, "Num episodes:", num_episodes)

    return mean_episode_reward

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
import gym
from stable_baselines3 import SAC

# Create the evaluation environment
eval_env = make_vec_env('Hopper-v4', seed=0, vec_env_cls=SubprocVecEnv,
                   wrapper_class=ChangeMassWrapper,
                   wrapper_kwargs=dict(torso_mass=3)
                   )

#eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=True)

# Load the trained SAC model
model = SAC.load("SAC_hopper_w3_3mil")

# Define variables to store the rewards
episode_rewards = []
total_timesteps = 0

# Set the number of episodes for evaluation
num_eval_episodes = 100

# Evaluate the model
for episode in range(num_eval_episodes):
    episode_reward = 0
    done = False
    obs = eval_env.reset()

    while not done:
        # Use the model to predict actions
        action, _ = model.predict(obs, deterministic=True)

        # Take the predicted action in the environment
        obs, reward, done, _ = eval_env.step(action)

        # Update the episode reward
        episode_reward += reward

        # Render the environment if desired
        #eval_env.render()

        # Increment the total timesteps
        total_timesteps += 1

    # Store the episode reward
    episode_rewards.append(episode_reward.flatten())
    print(f"Episode {episode + 1}: Reward = {episode_reward.flatten()}")

# Calculate the mean and standard deviation of rewards
mean_reward = sum(episode_rewards) / num_eval_episodes
std_reward = np.std(episode_rewards)

print(f"Mean Reward: {mean_reward:.2f}")
print(f"Std Reward: {std_reward:.2f}")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-47-b0aab60d00e8> in <cell line: 23>()
#      37
#      38         # Render the environment if desired
# ---> 39         eval_env.render()
#      40
#      41         # Increment the total timesteps
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py in render(self, mode)
#     175         """
#     176         try:
# --> 177             imgs = self.get_images()
#     178         except NotImplementedError:
#     179             warnings.warn(f"Render not defined for {self}")
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/subproc_vec_env.py in get_images(self)
#     151             # `mode` will be taken into account later
#     152             pipe.send(("render", "rgb_array"))
# --> 153         imgs = [pipe.recv() for pipe in self.remotes]
#     154         return imgs
#     155
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/subproc_vec_env.py in <listcomp>(.0)
#     151             # `mode` will be taken into account later
#     152             pipe.send(("render", "rgb_array"))
# --> 153         imgs = [pipe.recv() for pipe in self.remotes]
#     154         return imgs
#     155
#
# /usr/lib/python3.10/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# /usr/lib/python3.10/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     412
#     413     def _recv_bytes(self, maxsize=None):
# --> 414         buf = self._recv(4)
#     415         size, = struct.unpack("!i", buf.getvalue())
#     416         if size == -1:
#
# /usr/lib/python3.10/multiprocessing/connection.py in _recv(self, size, read)
#     381             if n == 0:
#     382                 if remaining == size:
# --> 383                     raise EOFError
#     384                 else:
#     385                     raise OSError("got end of file during message")
#
# EOFError:

# %%
import csv



# Specify the file path and name for the CSV file
csv_file = "episode_rewards_hopper_w9.csv"

# Open the CSV file in write mode
with open(csv_file, mode='w') as file:
    writer = csv.writer(file)

    # Write the list as a row in the CSV file
    writer.writerow(episode_rewards)

print("List saved as CSV successfully!")
# Out:
# List saved as CSV successfully!
